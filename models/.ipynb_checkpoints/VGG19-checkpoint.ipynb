# %%
import numpy as np
import os
import pandas as pd
import torch
import torch.nn as nn
from torchvision import datasets
from torchvision import transforms
from torch.utils.data.sampler import SubsetRandomSampler
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
from torchmetrics import Accuracy
import random
from tqdm.auto import tqdm
from timeit import default_timer as timer


# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
IMAGE_SIZE = (64, 64)  # Setting image size to 64*64, default is 224*224

# Define transform to resize and convert to tensor
transform = transforms.Compose([
    transforms.Resize(IMAGE_SIZE),
    transforms.ToTensor()
])

# Load the dataset
# Replace with your dataset directory
dataset_path = r"PATH_TO_TRAIN_DATA"
dataset = datasets.ImageFolder(root=dataset_path, transform=transform)

# Create the DataLoader
loader = DataLoader(dataset, batch_size=64, shuffle=False, num_workers=4)

# Initialize mean and std
mean = 0.0
std = 0.0
total_images_count = 0

# Compute mean and std over the entire dataset
print("Calculating mean and std...")
for images, _ in loader:
    batch_samples = images.size(0)  # batch size (last batch can have smaller size!)
    images = images.view(batch_samples, images.size(1), -1)  # reshape to (B, C, H*W)
    
    mean += images.mean(2).sum(0)
    std += images.std(2).sum(0)
    total_images_count += batch_samples

mean /= total_images_count
std /= total_images_count

print(f"Mean: {mean}")
print(f"Std: {std}")
# Out:
# Calculating mean and std...
# Mean: tensor([0.4531, 0.4513, 0.3910])
# Std: tensor([0.1808, 0.1760, 0.1748])

# %%
# Define transforms for train_dataset
train_transforms = transforms.Compose([
    transforms.RandomResizedCrop(64),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(mean, std),
])

# Define transforms for val_dataset
val_transforms = transforms.Compose([
    transforms.Resize((64,64)),
    transforms.ToTensor(),
    transforms.Normalize(mean, std),
])

# %%
train_dataset = ImageFolder(r"PATH_TO_TRAIN_DATA",transform= train_transforms)
val_dataset = ImageFolder(r"PATH_TO_VALIDATION_DATA", transform= val_transforms)

train_loader= DataLoader(train_dataset,batch_size=128,shuffle=True,num_workers=4)
val_loader= DataLoader(val_dataset,batch_size=128,shuffle=False,num_workers=4)

# %%
def save_epoch_metrics_csv(model_name, train_loss_history, val_loss_history,
                           train_acc_history, val_top1_acc_history, val_top5_acc_history,
                           filename=None):
    metrics_dict = {
        "epoch": list(range(1, len(train_loss_history) + 1)),
        "train_loss": train_loss_history,
        "val_loss": val_loss_history,
        "train_acc": train_acc_history,
        "val_top1": val_top1_acc_history,
        "val_top5": val_top5_acc_history,
    }
    df = pd.DataFrame(metrics_dict)

    if filename is None:
        filename = f"results/per_model_logs/{model_name}_metrics.csv"
    # Ensure directory exists
    os.makedirs(os.path.dirname(filename), exist_ok=True)
    df.to_csv(filename, index=False)
    print(f"[✓] Saved epoch metrics to {filename}")


def append_model_summary(model_name, train_loss_history, val_loss_history,
                         train_acc_history, val_top1_acc_history, val_top5_acc_history,
                         total_train_time_sec, model, batch_size, optimizer_type,
                         lr_schedule_desc, image_size, architecture_type,
                         summary_csv_path="results/summary/final_model_comparison.csv"):

    num_params = sum(p.numel() for p in model.parameters() if p.requires_grad)

    summary_dict = {
        "model_name": model_name,
        "final_train_loss": train_loss_history[-1],
        "final_val_loss": val_loss_history[-1],
        "final_train_acc": train_acc_history[-1],
        "final_val_top1_acc": val_top1_acc_history[-1],
        "final_val_top5_acc": val_top5_acc_history[-1],
        "total_train_time_sec": total_train_time_sec,
        "total_train_time_min": round(total_train_time_sec / 60, 2),
        "num_params": num_params,
        "batch_size": batch_size,
        "optimizer": optimizer_type,
        "learning_rate_schedule": lr_schedule_desc,
        "image_size": image_size,
        "architecture_type": architecture_type,
    }

    # Ensure output directory exists
    os.makedirs(os.path.dirname(summary_csv_path), exist_ok=True)

    # Append or create
    if os.path.exists(summary_csv_path):
        existing_df = pd.read_csv(summary_csv_path)
        updated_df = pd.concat([existing_df, pd.DataFrame([summary_dict])], ignore_index=True)
    else:
        updated_df = pd.DataFrame([summary_dict])

    updated_df.to_csv(summary_csv_path, index=False)
    print(f"[✓] Appended model summary to {summary_csv_path}")

# %%
# Analyzing time taken to train the model
def print_train_time(start: float,
                     end: float,
                     device: torch.device = None):
  total_time = end-start
  print(f"Train time on {device} : {total_time:.3f} seconds")
  return total_time

# %%
def train_model(
    model,
    train_loader,
    val_loader,
    loss_fn,
    optimizer_adam,
    optimizer_sgd,
    scheduler_adam,
    scheduler_sgd,
    epochs,
    batch_size,
    image_size,
    architecture_type,
    model_name
):
    # Track metrics
    train_loss_history, val_loss_history = [], []
    train_acc_history, val_top1_acc_history, val_top5_acc_history = [], [], []

    best_top1 = 0.0
    best_model_wts = None

    start_time = timer()

    for epoch in tqdm(range(epochs)):
        print(f"\nEpoch {epoch+1}/{epochs}\n{'-'*20}")

        # ----------------
        # Select optimizer
        # ----------------
        if epoch < 30:
            optimizer = optimizer_adam
            scheduler = scheduler_adam
        else:
            optimizer = optimizer_sgd
            scheduler = scheduler_sgd

        # ----------------
        # Training Phase
        # ----------------
        model.train()
        running_loss = 0.0
        running_correct = 0
        total_samples_train = 0

        for X, y in train_loader:
            X, y = X.to(device), y.to(device)
            batch_size_curr = y.size(0)
            total_samples_train += batch_size_curr

            outputs = model(X).float()
            loss = loss_fn(outputs, y)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            running_loss += loss.item() * batch_size_curr
            running_correct += (outputs.argmax(dim=1) == y).sum().item()

        train_loss = running_loss / total_samples_train
        train_acc = (running_correct / total_samples_train) * 100

        # ----------------
        # Validation Phase
        # ----------------
        model.eval()
        val_loss_total = 0.0
        val_samples_total = 0
        correct_top1 = 0
        correct_top5 = 0

        with torch.inference_mode():
            for X, y in val_loader:
                X, y = X.to(device), y.to(device)
                batch_size_curr = y.size(0)
                val_samples_total += batch_size_curr

                outputs = model(X).float()
                loss = loss_fn(outputs, y)
                val_loss_total += loss.item() * batch_size_curr

                _, pred_topk = outputs.topk(5, dim=1, largest=True, sorted=True)
                correct = pred_topk.eq(y.view(-1, 1).expand_as(pred_topk))

                correct_top1 += correct[:, :1].sum().item()
                correct_top5 += correct[:, :5].sum().item()

        val_loss = val_loss_total / val_samples_total
        top1_val_acc = (correct_top1 / val_samples_total) * 100
        top5_val_acc = (correct_top5 / val_samples_total) * 100

        # ----------------
        # Logging
        # ----------------
        print(f"Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.2f}%")
        print(f"Val Loss: {val_loss:.4f} | Top-1 Val Acc: {top1_val_acc:.2f}% | Top-5 Val Acc: {top5_val_acc:.2f}%")

        train_loss_history.append(train_loss)
        val_loss_history.append(val_loss)
        train_acc_history.append(train_acc)
        val_top1_acc_history.append(top1_val_acc)
        val_top5_acc_history.append(top5_val_acc)

        # Save best model
        if top1_val_acc > best_top1:
            best_top1 = top1_val_acc
            best_model_wts = model.state_dict().copy()
            os.makedirs("results/checkpoints", exist_ok=True)
            torch.save(best_model_wts, f"results/checkpoints/{model_name}_best.pth")
            print(f"[✓] Saved best model (Top-1 = {best_top1:.2f}%)")

        scheduler.step()

    end_time = timer()
    total_train_time_sec = end_time - start_time

    # Save metrics CSV
    save_epoch_metrics_csv(
        model_name=model_name,
        train_loss_history=train_loss_history,
        val_loss_history=val_loss_history,
        train_acc_history=train_acc_history,
        val_top1_acc_history=val_top1_acc_history,
        val_top5_acc_history=val_top5_acc_history
    )

    # Append summary CSV
    append_model_summary(
        model_name=model_name,
        train_loss_history=train_loss_history,
        val_loss_history=val_loss_history,
        train_acc_history=train_acc_history,
        val_top1_acc_history=val_top1_acc_history,
        val_top5_acc_history=val_top5_acc_history,
        total_train_time_sec=total_train_time_sec,
        model=model,
        batch_size=batch_size,
        optimizer_type="Adam (first 30 epochs) + SGD (rest)",
        lr_schedule_desc="StepLR: Adam(step=10, gamma=0.1), SGD(step=30, gamma=0.1)",
        image_size=f"{image_size[0]}x{image_size[1]}",
        architecture_type=architecture_type
    )

    print_train_time(start_time, end_time, device)
    print(f"[✓] Training complete for {model_name}")

# %%
class VGG19(nn.Module):
    def __init__(self,num_classes):
        super(VGG19,self).__init__()
        self.layer1 = nn.Sequential(
            nn.Conv2d(3,64,kernel_size = 3,stride=1,padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(),       
            
            nn.Conv2d(64,64,kernel_size=3,stride=1,padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2,stride=2),
            
            nn.Conv2d(64,128,kernel_size=3,stride=1,padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            
            nn.Conv2d(128,128,kernel_size=3,stride=1,padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2,stride=2),
            
            nn.Conv2d(128,256,kernel_size=3,stride=1,padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            
            nn.Conv2d(256,256,kernel_size=3,stride=1,padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(),

            nn.Conv2d(256,256,kernel_size=3,stride=1,padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(),

            nn.Conv2d(256,256,kernel_size=3,stride=1,padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2,stride=2),

            nn.Conv2d(256,512,kernel_size=3,stride=1,padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(),

            nn.Conv2d(512,512,kernel_size=3,stride=1,padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(),

            nn.Conv2d(512,512,kernel_size=3,stride=1,padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(),

            nn.Conv2d(512,512,kernel_size=3,stride=1,padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2,stride=2),

            nn.Conv2d(512,512,kernel_size=3,stride=1,padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(),

            nn.Conv2d(512,512,kernel_size=3,stride=1,padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(),

            nn.Conv2d(512,512,kernel_size=3,stride=1,padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(),

            nn.Conv2d(512,512,kernel_size=3,stride=1,padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2,stride=2),
            nn.Flatten(),

            nn.Dropout(0.5),
            nn.Linear(2*2*512, 4096),
            nn.ReLU(),

            nn.Dropout(0.5),
            nn.Linear(4096, 4096),
            nn.ReLU(),

            nn.Linear(4096, num_classes))

    def forward(self,x):
        return self.layer1(x)

# %%
model = VGG19(num_classes=100).to(device)

# Defining loss function
loss_fn = nn.CrossEntropyLoss()

# Defining optimizers
optimizer_adam = torch.optim.Adam(model.parameters(), lr=1e-4, weight_decay=1e-4)
optimizer_sgd = torch.optim.SGD(model.parameters(), lr=0.01, momentum=0.9, weight_decay=5e-4)

# Using learning rate schedulers 
scheduler_adam = torch.optim.lr_scheduler.StepLR(optimizer_adam, step_size=10, gamma=0.1)
scheduler_sgd = torch.optim.lr_scheduler.StepLR(optimizer_sgd, step_size=30, gamma=0.1)

train_model(
    model=model,
    train_loader=train_loader,
    val_loader=val_loader,
    loss_fn=loss_fn,
    optimizer_adam=optimizer_adam,
    optimizer_sgd=optimizer_sgd,
    scheduler_adam=scheduler_adam,
    scheduler_sgd=scheduler_sgd,
    epochs=100,
    batch_size=128,
    image_size=(64, 64),
    architecture_type="VGG19",
    model_name="VGG19_ImageNet100"
)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 1/100
# --------------------
# Train Loss: 4.0510 | Train Acc: 6.56%
# Val Loss: 3.7973 | Top-1 Val Acc: 10.24% | Top-5 Val Acc: 32.96%
# [✓] Saved best model (Top-1 = 10.24%)
#
# Epoch 2/100
# --------------------
# Train Loss: 3.5180 | Train Acc: 14.58%
# Val Loss: 3.3871 | Top-1 Val Acc: 17.18% | Top-5 Val Acc: 45.00%
# [✓] Saved best model (Top-1 = 17.18%)
#
# Epoch 3/100
# --------------------
# Train Loss: 3.1878 | Train Acc: 21.01%
# Val Loss: 3.2040 | Top-1 Val Acc: 20.60% | Top-5 Val Acc: 50.12%
# [✓] Saved best model (Top-1 = 20.60%)
#
# Epoch 4/100
# --------------------
# Train Loss: 2.9374 | Train Acc: 25.94%
# Val Loss: 2.9181 | Top-1 Val Acc: 25.90% | Top-5 Val Acc: 57.42%
# [✓] Saved best model (Top-1 = 25.90%)
#
# Epoch 5/100
# --------------------
# Train Loss: 2.7442 | Train Acc: 30.12%
# Val Loss: 2.7478 | Top-1 Val Acc: 30.32% | Top-5 Val Acc: 61.06%
# [✓] Saved best model (Top-1 = 30.32%)
#
# Epoch 6/100
# --------------------
# Train Loss: 2.5768 | Train Acc: 33.88%
# Val Loss: 2.6414 | Top-1 Val Acc: 33.88% | Top-5 Val Acc: 63.46%
# [✓] Saved best model (Top-1 = 33.88%)
#
# Epoch 7/100
# --------------------
# Train Loss: 2.4462 | Train Acc: 36.72%
# Val Loss: 2.4376 | Top-1 Val Acc: 37.00% | Top-5 Val Acc: 68.20%
# [✓] Saved best model (Top-1 = 37.00%)
#
# Epoch 8/100
# --------------------
# Train Loss: 2.3387 | Train Acc: 39.36%
# Val Loss: 2.4766 | Top-1 Val Acc: 36.66% | Top-5 Val Acc: 67.42%
#
# Epoch 9/100
# --------------------
# Train Loss: 2.2301 | Train Acc: 41.78%
# Val Loss: 2.4033 | Top-1 Val Acc: 39.22% | Top-5 Val Acc: 68.06%
# [✓] Saved best model (Top-1 = 39.22%)
#
# Epoch 10/100
# --------------------
# Train Loss: 2.1504 | Train Acc: 43.69%
# Val Loss: 2.3271 | Top-1 Val Acc: 41.50% | Top-5 Val Acc: 70.00%
# [✓] Saved best model (Top-1 = 41.50%)
#
# Epoch 11/100
# --------------------
# Train Loss: 1.8961 | Train Acc: 49.64%
# Val Loss: 1.9180 | Top-1 Val Acc: 49.42% | Top-5 Val Acc: 76.54%
# [✓] Saved best model (Top-1 = 49.42%)
#
# Epoch 12/100
# --------------------
# Train Loss: 1.8340 | Train Acc: 51.10%
# Val Loss: 1.9057 | Top-1 Val Acc: 49.66% | Top-5 Val Acc: 77.24%
# [✓] Saved best model (Top-1 = 49.66%)
#
# Epoch 13/100
# --------------------
# Train Loss: 1.7991 | Train Acc: 51.99%
# Val Loss: 1.8817 | Top-1 Val Acc: 50.34% | Top-5 Val Acc: 77.76%
# [✓] Saved best model (Top-1 = 50.34%)
#
# Epoch 14/100
# --------------------
# Train Loss: 1.7725 | Train Acc: 52.44%
# Val Loss: 1.8720 | Top-1 Val Acc: 50.68% | Top-5 Val Acc: 77.80%
# [✓] Saved best model (Top-1 = 50.68%)
#
# Epoch 15/100
# --------------------
# Train Loss: 1.7651 | Train Acc: 52.73%
# Val Loss: 1.8583 | Top-1 Val Acc: 50.74% | Top-5 Val Acc: 77.88%
# [✓] Saved best model (Top-1 = 50.74%)
#
# Epoch 16/100
# --------------------
# Train Loss: 1.7409 | Train Acc: 53.35%
# Val Loss: 1.8440 | Top-1 Val Acc: 51.42% | Top-5 Val Acc: 78.10%
# [✓] Saved best model (Top-1 = 51.42%)
#
# Epoch 17/100
# --------------------
# Train Loss: 1.7305 | Train Acc: 53.73%
# Val Loss: 1.8346 | Top-1 Val Acc: 51.58% | Top-5 Val Acc: 78.32%
# [✓] Saved best model (Top-1 = 51.58%)
#
# Epoch 18/100
# --------------------
# Train Loss: 1.7112 | Train Acc: 54.14%
# Val Loss: 1.8367 | Top-1 Val Acc: 51.84% | Top-5 Val Acc: 78.60%
# [✓] Saved best model (Top-1 = 51.84%)
#
# Epoch 19/100
# --------------------
# Train Loss: 1.7000 | Train Acc: 54.37%
# Val Loss: 1.8111 | Top-1 Val Acc: 52.40% | Top-5 Val Acc: 79.10%
# [✓] Saved best model (Top-1 = 52.40%)
#
# Epoch 20/100
# --------------------
# Train Loss: 1.6844 | Train Acc: 54.68%
# Val Loss: 1.8081 | Top-1 Val Acc: 52.02% | Top-5 Val Acc: 78.96%
#
# Epoch 21/100
# --------------------
# Train Loss: 1.6567 | Train Acc: 55.65%
# Val Loss: 1.7991 | Top-1 Val Acc: 52.52% | Top-5 Val Acc: 79.40%
# [✓] Saved best model (Top-1 = 52.52%)
#
# Epoch 22/100
# --------------------
# Train Loss: 1.6459 | Train Acc: 55.56%
# Val Loss: 1.7919 | Top-1 Val Acc: 52.78% | Top-5 Val Acc: 79.10%
# [✓] Saved best model (Top-1 = 52.78%)
#
# Epoch 23/100
# --------------------
# Train Loss: 1.6418 | Train Acc: 55.74%
# Val Loss: 1.8031 | Top-1 Val Acc: 52.72% | Top-5 Val Acc: 79.24%
#
# Epoch 24/100
# --------------------
# Train Loss: 1.6384 | Train Acc: 55.90%
# Val Loss: 1.7865 | Top-1 Val Acc: 52.66% | Top-5 Val Acc: 79.40%
#
# Epoch 25/100
# --------------------
# Train Loss: 1.6355 | Train Acc: 55.85%
# Val Loss: 1.7912 | Top-1 Val Acc: 53.10% | Top-5 Val Acc: 79.18%
# [✓] Saved best model (Top-1 = 53.10%)
#
# Epoch 26/100
# --------------------
# Train Loss: 1.6333 | Train Acc: 55.91%
# Val Loss: 1.7936 | Top-1 Val Acc: 53.12% | Top-5 Val Acc: 79.18%
# [✓] Saved best model (Top-1 = 53.12%)
#
# Epoch 27/100
# --------------------
# Train Loss: 1.6221 | Train Acc: 56.08%
# Val Loss: 1.7855 | Top-1 Val Acc: 52.90% | Top-5 Val Acc: 79.26%
#
# Epoch 28/100
# --------------------
# Train Loss: 1.6356 | Train Acc: 55.92%
# Val Loss: 1.7851 | Top-1 Val Acc: 52.96% | Top-5 Val Acc: 79.58%
#
# Epoch 29/100
# --------------------
# Train Loss: 1.6252 | Train Acc: 56.13%
# Val Loss: 1.7817 | Top-1 Val Acc: 53.02% | Top-5 Val Acc: 79.50%
#
# Epoch 30/100
# --------------------
# Train Loss: 1.6240 | Train Acc: 56.15%
# Val Loss: 1.7870 | Top-1 Val Acc: 53.12% | Top-5 Val Acc: 79.34%
#
# Epoch 31/100
# --------------------
# Train Loss: 2.3751 | Train Acc: 39.72%
# Val Loss: 2.2892 | Top-1 Val Acc: 41.48% | Top-5 Val Acc: 70.12%
#
# Epoch 32/100
# --------------------
# Train Loss: 2.1046 | Train Acc: 45.32%
# Val Loss: 2.2584 | Top-1 Val Acc: 41.78% | Top-5 Val Acc: 71.78%
#
# Epoch 33/100
# --------------------
# Train Loss: 2.0037 | Train Acc: 47.68%
# Val Loss: 2.1600 | Top-1 Val Acc: 44.58% | Top-5 Val Acc: 72.94%
#
# Epoch 34/100
# --------------------
# Train Loss: 1.9307 | Train Acc: 49.16%
# Val Loss: 2.0677 | Top-1 Val Acc: 46.26% | Top-5 Val Acc: 74.42%
#
# Epoch 35/100
# --------------------
# Train Loss: 1.8746 | Train Acc: 50.66%
# Val Loss: 2.0304 | Top-1 Val Acc: 46.66% | Top-5 Val Acc: 75.30%
#
# Epoch 36/100
# --------------------
# Train Loss: 1.8167 | Train Acc: 52.00%
# Val Loss: 1.9242 | Top-1 Val Acc: 49.46% | Top-5 Val Acc: 76.56%
#
# Epoch 37/100
# --------------------
# Train Loss: 1.7744 | Train Acc: 53.01%
# Val Loss: 1.8585 | Top-1 Val Acc: 51.20% | Top-5 Val Acc: 78.66%
#
# Epoch 38/100
# --------------------
# Train Loss: 1.7311 | Train Acc: 53.98%
# Val Loss: 1.9024 | Top-1 Val Acc: 50.96% | Top-5 Val Acc: 77.82%
#
# Epoch 39/100
# --------------------
# Train Loss: 1.6926 | Train Acc: 55.04%
# Val Loss: 1.8594 | Top-1 Val Acc: 50.72% | Top-5 Val Acc: 77.46%
#
# Epoch 40/100
# --------------------
# Train Loss: 1.6555 | Train Acc: 55.85%
# Val Loss: 1.9419 | Top-1 Val Acc: 50.72% | Top-5 Val Acc: 76.64%
#
# Epoch 41/100
# --------------------
# Train Loss: 1.6272 | Train Acc: 56.72%
# Val Loss: 1.7671 | Top-1 Val Acc: 53.36% | Top-5 Val Acc: 80.82%
# [✓] Saved best model (Top-1 = 53.36%)
#
# Epoch 42/100
# --------------------
# Train Loss: 1.5998 | Train Acc: 57.49%
# Val Loss: 1.7567 | Top-1 Val Acc: 53.88% | Top-5 Val Acc: 80.00%
# [✓] Saved best model (Top-1 = 53.88%)
#
# Epoch 43/100
# --------------------
# Train Loss: 1.5703 | Train Acc: 58.14%
# Val Loss: 1.7514 | Top-1 Val Acc: 54.54% | Top-5 Val Acc: 80.04%
# [✓] Saved best model (Top-1 = 54.54%)
#
# Epoch 44/100
# --------------------
# Train Loss: 1.5473 | Train Acc: 58.81%
# Val Loss: 1.8927 | Top-1 Val Acc: 51.74% | Top-5 Val Acc: 78.84%
#
# Epoch 45/100
# --------------------
# Train Loss: 1.5296 | Train Acc: 59.21%
# Val Loss: 1.7166 | Top-1 Val Acc: 54.62% | Top-5 Val Acc: 81.52%
# [✓] Saved best model (Top-1 = 54.62%)
#
# Epoch 46/100
# --------------------
# Train Loss: 1.5020 | Train Acc: 59.90%
# Val Loss: 1.7064 | Top-1 Val Acc: 55.60% | Top-5 Val Acc: 81.30%
# [✓] Saved best model (Top-1 = 55.60%)
#
# Epoch 47/100
# --------------------
# Train Loss: 1.4765 | Train Acc: 60.69%
# Val Loss: 1.6435 | Top-1 Val Acc: 56.84% | Top-5 Val Acc: 82.40%
# [✓] Saved best model (Top-1 = 56.84%)
#
# Epoch 48/100
# --------------------
# Train Loss: 1.4634 | Train Acc: 60.94%
# Val Loss: 1.5993 | Top-1 Val Acc: 58.22% | Top-5 Val Acc: 82.98%
# [✓] Saved best model (Top-1 = 58.22%)
#
# Epoch 49/100
# --------------------
# Train Loss: 1.4475 | Train Acc: 61.35%
# Val Loss: 1.6935 | Top-1 Val Acc: 56.24% | Top-5 Val Acc: 81.20%
#
# Epoch 50/100
# --------------------
# Train Loss: 1.4366 | Train Acc: 61.76%
# Val Loss: 1.5857 | Top-1 Val Acc: 58.36% | Top-5 Val Acc: 83.82%
# [✓] Saved best model (Top-1 = 58.36%)
#
# Epoch 51/100
# --------------------
# Train Loss: 1.4160 | Train Acc: 62.26%
# Val Loss: 1.6321 | Top-1 Val Acc: 57.28% | Top-5 Val Acc: 82.34%
#
# Epoch 52/100
# --------------------
# Train Loss: 1.4046 | Train Acc: 62.56%
# Val Loss: 1.6143 | Top-1 Val Acc: 58.24% | Top-5 Val Acc: 81.68%
#
# Epoch 53/100
# --------------------
# Train Loss: 1.3935 | Train Acc: 62.80%
# Val Loss: 1.5737 | Top-1 Val Acc: 59.26% | Top-5 Val Acc: 82.98%
# [✓] Saved best model (Top-1 = 59.26%)
#
# Epoch 54/100
# --------------------
# Train Loss: 1.3796 | Train Acc: 63.03%
# Val Loss: 1.6106 | Top-1 Val Acc: 57.78% | Top-5 Val Acc: 82.32%
#
# Epoch 55/100
# --------------------
# Train Loss: 1.3699 | Train Acc: 63.42%
# Val Loss: 1.5827 | Top-1 Val Acc: 57.96% | Top-5 Val Acc: 83.12%
#
# Epoch 56/100
# --------------------
# Train Loss: 1.3673 | Train Acc: 63.57%
# Val Loss: 1.5798 | Top-1 Val Acc: 59.62% | Top-5 Val Acc: 83.06%
# [✓] Saved best model (Top-1 = 59.62%)
#
# Epoch 57/100
# --------------------
# Train Loss: 1.3498 | Train Acc: 64.18%
# Val Loss: 1.5090 | Top-1 Val Acc: 60.02% | Top-5 Val Acc: 84.48%
# [✓] Saved best model (Top-1 = 60.02%)
#
# Epoch 58/100
# --------------------
# Train Loss: 1.3358 | Train Acc: 64.53%
# Val Loss: 1.5882 | Top-1 Val Acc: 59.08% | Top-5 Val Acc: 82.88%
#
# Epoch 59/100
# --------------------
# Train Loss: 1.3299 | Train Acc: 64.50%
# Val Loss: 1.5534 | Top-1 Val Acc: 59.32% | Top-5 Val Acc: 83.90%
#
# Epoch 60/100
# --------------------
# Train Loss: 1.3210 | Train Acc: 64.83%
# Val Loss: 1.5213 | Top-1 Val Acc: 59.68% | Top-5 Val Acc: 83.90%
#
# Epoch 61/100
# --------------------
# Train Loss: 1.0541 | Train Acc: 71.45%
# Val Loss: 1.1781 | Top-1 Val Acc: 68.70% | Top-5 Val Acc: 88.64%
# [✓] Saved best model (Top-1 = 68.70%)
#
# Epoch 62/100
# --------------------
# Train Loss: 0.9911 | Train Acc: 72.87%
# Val Loss: 1.1527 | Top-1 Val Acc: 69.20% | Top-5 Val Acc: 88.76%
# [✓] Saved best model (Top-1 = 69.20%)
#
# Epoch 63/100
# --------------------
# Train Loss: 0.9577 | Train Acc: 73.66%
# Val Loss: 1.1444 | Top-1 Val Acc: 69.62% | Top-5 Val Acc: 89.34%
# [✓] Saved best model (Top-1 = 69.62%)
#
# Epoch 64/100
# --------------------
# Train Loss: 0.9388 | Train Acc: 74.12%
# Val Loss: 1.1470 | Top-1 Val Acc: 69.74% | Top-5 Val Acc: 89.32%
# [✓] Saved best model (Top-1 = 69.74%)
#
# Epoch 65/100
# --------------------
# Train Loss: 0.9210 | Train Acc: 74.56%
# Val Loss: 1.1437 | Top-1 Val Acc: 69.72% | Top-5 Val Acc: 89.52%
#
# Epoch 66/100
# --------------------
# Train Loss: 0.9106 | Train Acc: 74.86%
# Val Loss: 1.1396 | Top-1 Val Acc: 69.98% | Top-5 Val Acc: 89.16%
# [✓] Saved best model (Top-1 = 69.98%)
#
# Epoch 67/100
# --------------------
# Train Loss: 0.8978 | Train Acc: 75.29%
# Val Loss: 1.1451 | Top-1 Val Acc: 69.20% | Top-5 Val Acc: 89.16%
#
# Epoch 68/100
# --------------------
# Train Loss: 0.8819 | Train Acc: 75.57%
# Val Loss: 1.1325 | Top-1 Val Acc: 69.92% | Top-5 Val Acc: 89.52%
#
# Epoch 69/100
# --------------------
# Train Loss: 0.8740 | Train Acc: 75.80%
# Val Loss: 1.1343 | Top-1 Val Acc: 69.80% | Top-5 Val Acc: 89.36%
#
# Epoch 70/100
# --------------------
# Train Loss: 0.8638 | Train Acc: 76.05%
# Val Loss: 1.1285 | Top-1 Val Acc: 70.42% | Top-5 Val Acc: 90.22%
# [✓] Saved best model (Top-1 = 70.42%)
#
# Epoch 71/100
# --------------------
# Train Loss: 0.8569 | Train Acc: 76.12%
# Val Loss: 1.1188 | Top-1 Val Acc: 70.26% | Top-5 Val Acc: 90.04%
#
# Epoch 72/100
# --------------------
# Train Loss: 0.8551 | Train Acc: 76.36%
# Val Loss: 1.1296 | Top-1 Val Acc: 70.12% | Top-5 Val Acc: 89.60%
#
# Epoch 73/100
# --------------------
# Train Loss: 0.8440 | Train Acc: 76.71%
# Val Loss: 1.1059 | Top-1 Val Acc: 70.64% | Top-5 Val Acc: 90.22%
# [✓] Saved best model (Top-1 = 70.64%)
#
# Epoch 74/100
# --------------------
# Train Loss: 0.8356 | Train Acc: 76.78%
# Val Loss: 1.1167 | Top-1 Val Acc: 70.68% | Top-5 Val Acc: 90.00%
# [✓] Saved best model (Top-1 = 70.68%)
#
# Epoch 75/100
# --------------------
# Train Loss: 0.8366 | Train Acc: 76.76%
# Val Loss: 1.1104 | Top-1 Val Acc: 70.26% | Top-5 Val Acc: 89.94%
#
# Epoch 76/100
# --------------------
# Train Loss: 0.8257 | Train Acc: 77.12%
# Val Loss: 1.1291 | Top-1 Val Acc: 70.04% | Top-5 Val Acc: 89.66%
#
# Epoch 77/100
# --------------------
# Train Loss: 0.8202 | Train Acc: 77.19%
# Val Loss: 1.1171 | Top-1 Val Acc: 70.14% | Top-5 Val Acc: 90.26%
#
# Epoch 78/100
# --------------------
# Train Loss: 0.8089 | Train Acc: 77.59%
# Val Loss: 1.1321 | Top-1 Val Acc: 70.30% | Top-5 Val Acc: 90.18%
#
# Epoch 79/100
# --------------------
# Train Loss: 0.8011 | Train Acc: 77.66%
# Val Loss: 1.1361 | Top-1 Val Acc: 70.54% | Top-5 Val Acc: 89.76%
#
# Epoch 80/100
# --------------------
# Train Loss: 0.7978 | Train Acc: 77.85%
# Val Loss: 1.1326 | Top-1 Val Acc: 70.52% | Top-5 Val Acc: 89.84%
#
# Epoch 81/100
# --------------------
# Train Loss: 0.7927 | Train Acc: 77.96%
# Val Loss: 1.1361 | Top-1 Val Acc: 70.48% | Top-5 Val Acc: 89.86%
#
# Epoch 82/100
# --------------------
# Train Loss: 0.7908 | Train Acc: 77.99%
# Val Loss: 1.1349 | Top-1 Val Acc: 70.52% | Top-5 Val Acc: 90.24%
#
# Epoch 83/100
# --------------------
# Train Loss: 0.7865 | Train Acc: 78.09%
# Val Loss: 1.1370 | Top-1 Val Acc: 70.74% | Top-5 Val Acc: 89.76%
# [✓] Saved best model (Top-1 = 70.74%)
#
# Epoch 84/100
# --------------------
# Train Loss: 0.7824 | Train Acc: 78.22%
# Val Loss: 1.1261 | Top-1 Val Acc: 71.20% | Top-5 Val Acc: 90.18%
# [✓] Saved best model (Top-1 = 71.20%)
#
# Epoch 85/100
# --------------------
# Train Loss: 0.7698 | Train Acc: 78.52%
# Val Loss: 1.1320 | Top-1 Val Acc: 70.92% | Top-5 Val Acc: 90.22%
#
# Epoch 86/100
# --------------------
# Train Loss: 0.7683 | Train Acc: 78.59%
# Val Loss: 1.1432 | Top-1 Val Acc: 70.58% | Top-5 Val Acc: 90.32%
#
# Epoch 87/100
# --------------------
# Train Loss: 0.7695 | Train Acc: 78.63%
# Val Loss: 1.1394 | Top-1 Val Acc: 70.44% | Top-5 Val Acc: 90.24%
#
# Epoch 88/100
# --------------------
# Train Loss: 0.7575 | Train Acc: 78.81%
# Val Loss: 1.1400 | Top-1 Val Acc: 70.28% | Top-5 Val Acc: 89.82%
#
# Epoch 89/100
# --------------------
# Train Loss: 0.7524 | Train Acc: 79.02%
# Val Loss: 1.1375 | Top-1 Val Acc: 71.10% | Top-5 Val Acc: 89.66%
#
# Epoch 90/100
# --------------------
# Train Loss: 0.7478 | Train Acc: 79.00%
# Val Loss: 1.1387 | Top-1 Val Acc: 70.62% | Top-5 Val Acc: 89.86%
#
# Epoch 91/100
# --------------------
# Train Loss: 0.7102 | Train Acc: 80.27%
# Val Loss: 1.1153 | Top-1 Val Acc: 71.26% | Top-5 Val Acc: 90.44%
# [✓] Saved best model (Top-1 = 71.26%)
#
# Epoch 92/100
# --------------------
# Train Loss: 0.6945 | Train Acc: 80.68%
# Val Loss: 1.1163 | Top-1 Val Acc: 71.02% | Top-5 Val Acc: 90.70%
#
# Epoch 93/100
# --------------------
# Train Loss: 0.6887 | Train Acc: 80.73%
# Val Loss: 1.1107 | Top-1 Val Acc: 71.18% | Top-5 Val Acc: 90.56%
#
# Epoch 94/100
# --------------------
# Train Loss: 0.6877 | Train Acc: 80.84%
# Val Loss: 1.1107 | Top-1 Val Acc: 71.30% | Top-5 Val Acc: 90.70%
# [✓] Saved best model (Top-1 = 71.30%)
#
# Epoch 95/100
# --------------------
# Train Loss: 0.6821 | Train Acc: 80.93%
# Val Loss: 1.1183 | Top-1 Val Acc: 70.86% | Top-5 Val Acc: 90.50%
#
# Epoch 96/100
# --------------------
# Train Loss: 0.6838 | Train Acc: 80.86%
# Val Loss: 1.1159 | Top-1 Val Acc: 71.18% | Top-5 Val Acc: 90.60%
#
# Epoch 97/100
# --------------------
# Train Loss: 0.6732 | Train Acc: 81.17%
# Val Loss: 1.1143 | Top-1 Val Acc: 71.20% | Top-5 Val Acc: 90.52%
#
# Epoch 98/100
# --------------------
# Train Loss: 0.6754 | Train Acc: 81.16%
# Val Loss: 1.1164 | Top-1 Val Acc: 71.72% | Top-5 Val Acc: 90.78%
# [✓] Saved best model (Top-1 = 71.72%)
#
# Epoch 99/100
# --------------------
# Train Loss: 0.6706 | Train Acc: 81.22%
# Val Loss: 1.1195 | Top-1 Val Acc: 71.16% | Top-5 Val Acc: 90.82%
#
# Epoch 100/100
# --------------------
# Train Loss: 0.6731 | Train Acc: 81.12%
# Val Loss: 1.1175 | Top-1 Val Acc: 71.36% | Top-5 Val Acc: 90.80%
# [✓] Saved epoch metrics to results/per_model_logs/VGG19_ImageNet100_metrics.csv
# [✓] Appended model summary to results/summary/final_model_comparison.csv
# Train time on cuda : 17447.489 seconds
# [✓] Training complete for VGG19_ImageNet100
