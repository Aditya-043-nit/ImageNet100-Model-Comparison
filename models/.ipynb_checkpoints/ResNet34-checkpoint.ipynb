# %%
import numpy as np
import os
import pandas as pd
import torch
import torch.nn as nn
from torchvision import datasets
from torchvision import transforms
from torch.utils.data.sampler import SubsetRandomSampler
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
from torchmetrics import Accuracy
import random
from tqdm.auto import tqdm
from timeit import default_timer as timer


# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
IMAGE_SIZE = (64, 64)  # Setting image size to 64*64, default is 224*224

# Define transform to resize and convert to tensor
transform = transforms.Compose([
    transforms.Resize(IMAGE_SIZE),
    transforms.ToTensor()
])

# Load the dataset
# Replace with your dataset directory
dataset_path = r"PATH_TO_TRAIN_DATA"
dataset = datasets.ImageFolder(root=dataset_path, transform=transform)

# Create the DataLoader
loader = DataLoader(dataset, batch_size=64, shuffle=False, num_workers=4)

# Initialize mean and std
mean = 0.0
std = 0.0
total_images_count = 0

# Compute mean and std over the entire dataset
print("Calculating mean and std...")
for images, _ in loader:
    batch_samples = images.size(0)  # batch size (last batch can have smaller size!)
    images = images.view(batch_samples, images.size(1), -1)  # reshape to (B, C, H*W)
    
    mean += images.mean(2).sum(0)
    std += images.std(2).sum(0)
    total_images_count += batch_samples

mean /= total_images_count
std /= total_images_count

print(f"Mean: {mean}")
print(f"Std: {std}")
# Out:
# Calculating mean and std...
# Mean: tensor([0.4531, 0.4513, 0.3910])
# Std: tensor([0.1808, 0.1760, 0.1748])

# %%
# Define transforms for train_dataset
train_transforms = transforms.Compose([
    transforms.RandomResizedCrop(64),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(mean, std),
])

# Define transforms for val_dataset
val_transforms = transforms.Compose([
    transforms.Resize((64,64)),
    transforms.ToTensor(),
    transforms.Normalize(mean, std),
])

# %%
train_dataset = ImageFolder(r"PATH_TO_TRAIN_DATA",transform= train_transforms)
val_dataset = ImageFolder(r"PATH_TO_VALIDATION_DATA", transform= val_transforms)

train_loader= DataLoader(train_dataset,batch_size=128,shuffle=True,num_workers=4)
val_loader= DataLoader(val_dataset,batch_size=128,shuffle=False,num_workers=4)

# %%
def save_epoch_metrics_csv(model_name, train_loss_history, val_loss_history,
                           train_acc_history, val_top1_acc_history, val_top5_acc_history,
                           filename=None):
    metrics_dict = {
        "epoch": list(range(1, len(train_loss_history) + 1)),
        "train_loss": train_loss_history,
        "val_loss": val_loss_history,
        "train_acc": train_acc_history,
        "val_top1": val_top1_acc_history,
        "val_top5": val_top5_acc_history,
    }
    df = pd.DataFrame(metrics_dict)

    if filename is None:
        filename = f"results/per_model_logs/{model_name}_metrics.csv"
    # Ensure directory exists
    os.makedirs(os.path.dirname(filename), exist_ok=True)
    df.to_csv(filename, index=False)
    print(f"[✓] Saved epoch metrics to {filename}")


def append_model_summary(model_name, train_loss_history, val_loss_history,
                         train_acc_history, val_top1_acc_history, val_top5_acc_history,
                         total_train_time_sec, model, batch_size, optimizer_type,
                         lr_schedule_desc, image_size, architecture_type,
                         summary_csv_path="results/summary/final_model_comparison.csv"):

    num_params = sum(p.numel() for p in model.parameters() if p.requires_grad)

    summary_dict = {
        "model_name": model_name,
        "final_train_loss": train_loss_history[-1],
        "final_val_loss": val_loss_history[-1],
        "final_train_acc": train_acc_history[-1],
        "final_val_top1_acc": val_top1_acc_history[-1],
        "final_val_top5_acc": val_top5_acc_history[-1],
        "total_train_time_sec": total_train_time_sec,
        "total_train_time_min": round(total_train_time_sec / 60, 2),
        "num_params": num_params,
        "batch_size": batch_size,
        "optimizer": optimizer_type,
        "learning_rate_schedule": lr_schedule_desc,
        "image_size": image_size,
        "architecture_type": architecture_type,
    }

    # Ensure output directory exists
    os.makedirs(os.path.dirname(summary_csv_path), exist_ok=True)

    # Append or create
    if os.path.exists(summary_csv_path):
        existing_df = pd.read_csv(summary_csv_path)
        updated_df = pd.concat([existing_df, pd.DataFrame([summary_dict])], ignore_index=True)
    else:
        updated_df = pd.DataFrame([summary_dict])

    updated_df.to_csv(summary_csv_path, index=False)
    print(f"[✓] Appended model summary to {summary_csv_path}")

# %%
# Analyzing time taken to train the model
def print_train_time(start: float,
                     end: float,
                     device: torch.device = None):
  total_time = end-start
  print(f"Train time on {device} : {total_time:.3f} seconds")
  return total_time

# %%
def train_model(
    model,
    train_loader,
    val_loader,
    loss_fn,
    optimizer_adam,
    optimizer_sgd,
    scheduler_adam,
    scheduler_sgd,
    epochs,
    batch_size,
    image_size,
    architecture_type,
    model_name
):
    # Track metrics
    train_loss_history, val_loss_history = [], []
    train_acc_history, val_top1_acc_history, val_top5_acc_history = [], [], []

    best_top1 = 0.0
    best_model_wts = None

    start_time = timer()

    for epoch in tqdm(range(epochs)):
        print(f"\nEpoch {epoch+1}/{epochs}\n{'-'*20}")

        # ----------------
        # Select optimizer
        # ----------------
        if epoch < 30:
            optimizer = optimizer_adam
            scheduler = scheduler_adam
        else:
            optimizer = optimizer_sgd
            scheduler = scheduler_sgd

        # ----------------
        # Training Phase
        # ----------------
        model.train()
        running_loss = 0.0
        running_correct = 0
        total_samples_train = 0

        for X, y in train_loader:
            X, y = X.to(device), y.to(device)
            batch_size_curr = y.size(0)
            total_samples_train += batch_size_curr

            outputs = model(X).float()
            loss = loss_fn(outputs, y)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            running_loss += loss.item() * batch_size_curr
            running_correct += (outputs.argmax(dim=1) == y).sum().item()

        train_loss = running_loss / total_samples_train
        train_acc = (running_correct / total_samples_train) * 100

        # ----------------
        # Validation Phase
        # ----------------
        model.eval()
        val_loss_total = 0.0
        val_samples_total = 0
        correct_top1 = 0
        correct_top5 = 0

        with torch.inference_mode():
            for X, y in val_loader:
                X, y = X.to(device), y.to(device)
                batch_size_curr = y.size(0)
                val_samples_total += batch_size_curr

                outputs = model(X).float()
                loss = loss_fn(outputs, y)
                val_loss_total += loss.item() * batch_size_curr

                _, pred_topk = outputs.topk(5, dim=1, largest=True, sorted=True)
                correct = pred_topk.eq(y.view(-1, 1).expand_as(pred_topk))

                correct_top1 += correct[:, :1].sum().item()
                correct_top5 += correct[:, :5].sum().item()

        val_loss = val_loss_total / val_samples_total
        top1_val_acc = (correct_top1 / val_samples_total) * 100
        top5_val_acc = (correct_top5 / val_samples_total) * 100

        # ----------------
        # Logging
        # ----------------
        print(f"Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.2f}%")
        print(f"Val Loss: {val_loss:.4f} | Top-1 Val Acc: {top1_val_acc:.2f}% | Top-5 Val Acc: {top5_val_acc:.2f}%")

        train_loss_history.append(train_loss)
        val_loss_history.append(val_loss)
        train_acc_history.append(train_acc)
        val_top1_acc_history.append(top1_val_acc)
        val_top5_acc_history.append(top5_val_acc)

        # Save best model
        if top1_val_acc > best_top1:
            best_top1 = top1_val_acc
            best_model_wts = model.state_dict().copy()
            os.makedirs("results/checkpoints", exist_ok=True)
            torch.save(best_model_wts, f"results/checkpoints/{model_name}_best.pth")
            print(f"[✓] Saved best model (Top-1 = {best_top1:.2f}%)")

        scheduler.step()

    end_time = timer()
    total_train_time_sec = end_time - start_time

    # Save metrics CSV
    save_epoch_metrics_csv(
        model_name=model_name,
        train_loss_history=train_loss_history,
        val_loss_history=val_loss_history,
        train_acc_history=train_acc_history,
        val_top1_acc_history=val_top1_acc_history,
        val_top5_acc_history=val_top5_acc_history
    )

    # Append summary CSV
    append_model_summary(
        model_name=model_name,
        train_loss_history=train_loss_history,
        val_loss_history=val_loss_history,
        train_acc_history=train_acc_history,
        val_top1_acc_history=val_top1_acc_history,
        val_top5_acc_history=val_top5_acc_history,
        total_train_time_sec=total_train_time_sec,
        model=model,
        batch_size=batch_size,
        optimizer_type="Adam (first 30 epochs) + SGD (rest)",
        lr_schedule_desc="StepLR: Adam(step=10, gamma=0.1), SGD(step=30, gamma=0.1)",
        image_size=f"{image_size[0]}x{image_size[1]}",
        architecture_type=architecture_type
    )

    print_train_time(start_time, end_time, device)
    print(f"[✓] Training complete for {model_name}")

# %%
class BasicBlock(nn.Module):
    def __init__(self,in_channels,out_channels,stride=1):
        super(BasicBlock,self) .__init__()

        self.residual_function = nn.Sequential(
            nn.Conv2d(in_channels,out_channels,kernel_size=3,stride=stride,padding=1,bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_channels,out_channels,kernel_size=3,padding=1,bias=False),
            nn.BatchNorm2d(out_channels)    
        )
        self.shortcut = nn.Sequential()
        if stride != 1or in_channels != out_channels:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channels,out_channels,kernel_size=1,stride=stride,bias=False),
                nn.BatchNorm2d(out_channels)
            )
        self.relu = nn.ReLU(inplace=True)

    def forward(self,x):
        out = self.residual_function(x)
        out += self.shortcut(x)
        return self.relu(out)


class ResNet34(nn.Module):
    def __init__(self,num_classes):
        super(ResNet34,self) .__init__()
        self.in_channels = 64
        self.layer = nn.Sequential(
            nn.Conv2d(3,64,kernel_size=7,stride=2,padding=3,bias=False),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3,stride=2,padding=1)
            )
        self.layer_1 = self.make_layer(64,3)
        self.layer_2 = self.make_layer(128,4,stride=2)
        self.layer_3 = self.make_layer(256,6,stride=2)
        self.layer_4 = self.make_layer(512,3,stride=2)

        self.avgpool = nn.AdaptiveAvgPool2d((1,1))
        self.fc = nn.Linear(512,num_classes)

    def make_layer(self,out_channels,blocks,stride=1):
        layers=[]
        layers.append(BasicBlock(self.in_channels,out_channels,stride))
        self.in_channels = out_channels
        for _ in range(1,blocks):
            layers.append(BasicBlock(out_channels,out_channels))
        return nn.Sequential(*layers)


    def forward(self,x):
        x = self.layer(x)
        x = self.layer_1(x)
        x = self.layer_2(x)
        x = self.layer_3(x)
        x = self.layer_4(x)
        x = self.avgpool(x)
        x = torch.flatten(x,1)
        x = self.fc(x)
        return x

# %%
model = ResNet34(num_classes=100).to(device)

# Defining loss function
loss_fn = nn.CrossEntropyLoss()

# Defining optimizers
optimizer_adam = torch.optim.Adam(model.parameters(), lr=1e-4, weight_decay=1e-4)
optimizer_sgd = torch.optim.SGD(model.parameters(), lr=0.01, momentum=0.9, weight_decay=5e-4)

# Using learning rate schedulers 
scheduler_adam = torch.optim.lr_scheduler.StepLR(optimizer_adam, step_size=10, gamma=0.1)
scheduler_sgd = torch.optim.lr_scheduler.StepLR(optimizer_sgd, step_size=30, gamma=0.1)

train_model(
    model=model,
    train_loader=train_loader,
    val_loader=val_loader,
    loss_fn=loss_fn,
    optimizer_adam=optimizer_adam,
    optimizer_sgd=optimizer_sgd,
    scheduler_adam=scheduler_adam,
    scheduler_sgd=scheduler_sgd,
    epochs=100,
    batch_size=128,
    image_size=(64, 64),
    architecture_type="ResNet34",
    model_name="ResNet34_ImageNet100"
)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 1/100
# --------------------
# Train Loss: 3.8077 | Train Acc: 11.63%
# Val Loss: 3.4808 | Top-1 Val Acc: 17.78% | Top-5 Val Acc: 42.78%
# [✓] Saved best model (Top-1 = 17.78%)
#
# Epoch 2/100
# --------------------
# Train Loss: 3.2702 | Train Acc: 21.02%
# Val Loss: 3.1507 | Top-1 Val Acc: 23.20% | Top-5 Val Acc: 51.28%
# [✓] Saved best model (Top-1 = 23.20%)
#
# Epoch 3/100
# --------------------
# Train Loss: 3.0126 | Train Acc: 25.97%
# Val Loss: 3.0251 | Top-1 Val Acc: 25.24% | Top-5 Val Acc: 55.02%
# [✓] Saved best model (Top-1 = 25.24%)
#
# Epoch 4/100
# --------------------
# Train Loss: 2.8332 | Train Acc: 29.91%
# Val Loss: 2.8895 | Top-1 Val Acc: 29.20% | Top-5 Val Acc: 58.64%
# [✓] Saved best model (Top-1 = 29.20%)
#
# Epoch 5/100
# --------------------
# Train Loss: 2.6888 | Train Acc: 32.77%
# Val Loss: 2.7013 | Top-1 Val Acc: 32.82% | Top-5 Val Acc: 61.28%
# [✓] Saved best model (Top-1 = 32.82%)
#
# Epoch 6/100
# --------------------
# Train Loss: 2.5733 | Train Acc: 35.37%
# Val Loss: 2.6773 | Top-1 Val Acc: 33.16% | Top-5 Val Acc: 63.12%
# [✓] Saved best model (Top-1 = 33.16%)
#
# Epoch 7/100
# --------------------
# Train Loss: 2.4755 | Train Acc: 37.38%
# Val Loss: 2.5908 | Top-1 Val Acc: 34.94% | Top-5 Val Acc: 64.56%
# [✓] Saved best model (Top-1 = 34.94%)
#
# Epoch 8/100
# --------------------
# Train Loss: 2.3841 | Train Acc: 39.36%
# Val Loss: 2.4963 | Top-1 Val Acc: 36.28% | Top-5 Val Acc: 66.06%
# [✓] Saved best model (Top-1 = 36.28%)
#
# Epoch 9/100
# --------------------
# Train Loss: 2.3066 | Train Acc: 40.98%
# Val Loss: 2.4603 | Top-1 Val Acc: 37.48% | Top-5 Val Acc: 66.56%
# [✓] Saved best model (Top-1 = 37.48%)
#
# Epoch 10/100
# --------------------
# Train Loss: 2.2362 | Train Acc: 42.62%
# Val Loss: 2.3726 | Top-1 Val Acc: 39.44% | Top-5 Val Acc: 69.46%
# [✓] Saved best model (Top-1 = 39.44%)
#
# Epoch 11/100
# --------------------
# Train Loss: 2.0205 | Train Acc: 47.40%
# Val Loss: 2.1751 | Top-1 Val Acc: 43.78% | Top-5 Val Acc: 72.62%
# [✓] Saved best model (Top-1 = 43.78%)
#
# Epoch 12/100
# --------------------
# Train Loss: 1.9709 | Train Acc: 48.63%
# Val Loss: 2.1572 | Top-1 Val Acc: 44.28% | Top-5 Val Acc: 72.94%
# [✓] Saved best model (Top-1 = 44.28%)
#
# Epoch 13/100
# --------------------
# Train Loss: 1.9473 | Train Acc: 49.30%
# Val Loss: 2.1384 | Top-1 Val Acc: 44.52% | Top-5 Val Acc: 73.26%
# [✓] Saved best model (Top-1 = 44.52%)
#
# Epoch 14/100
# --------------------
# Train Loss: 1.9255 | Train Acc: 49.63%
# Val Loss: 2.1211 | Top-1 Val Acc: 44.96% | Top-5 Val Acc: 73.88%
# [✓] Saved best model (Top-1 = 44.96%)
#
# Epoch 15/100
# --------------------
# Train Loss: 1.9117 | Train Acc: 49.93%
# Val Loss: 2.1224 | Top-1 Val Acc: 45.34% | Top-5 Val Acc: 73.64%
# [✓] Saved best model (Top-1 = 45.34%)
#
# Epoch 16/100
# --------------------
# Train Loss: 1.8923 | Train Acc: 50.31%
# Val Loss: 2.1062 | Top-1 Val Acc: 45.66% | Top-5 Val Acc: 74.46%
# [✓] Saved best model (Top-1 = 45.66%)
#
# Epoch 17/100
# --------------------
# Train Loss: 1.8758 | Train Acc: 50.80%
# Val Loss: 2.1151 | Top-1 Val Acc: 45.38% | Top-5 Val Acc: 74.14%
#
# Epoch 18/100
# --------------------
# Train Loss: 1.8627 | Train Acc: 50.97%
# Val Loss: 2.0959 | Top-1 Val Acc: 45.70% | Top-5 Val Acc: 74.10%
# [✓] Saved best model (Top-1 = 45.70%)
#
# Epoch 19/100
# --------------------
# Train Loss: 1.8498 | Train Acc: 51.35%
# Val Loss: 2.0999 | Top-1 Val Acc: 46.20% | Top-5 Val Acc: 74.20%
# [✓] Saved best model (Top-1 = 46.20%)
#
# Epoch 20/100
# --------------------
# Train Loss: 1.8378 | Train Acc: 51.72%
# Val Loss: 2.0764 | Top-1 Val Acc: 46.38% | Top-5 Val Acc: 74.76%
# [✓] Saved best model (Top-1 = 46.38%)
#
# Epoch 21/100
# --------------------
# Train Loss: 1.8060 | Train Acc: 52.42%
# Val Loss: 2.0666 | Top-1 Val Acc: 46.34% | Top-5 Val Acc: 74.90%
#
# Epoch 22/100
# --------------------
# Train Loss: 1.8004 | Train Acc: 52.59%
# Val Loss: 2.0637 | Top-1 Val Acc: 46.58% | Top-5 Val Acc: 74.96%
# [✓] Saved best model (Top-1 = 46.58%)
#
# Epoch 23/100
# --------------------
# Train Loss: 1.8050 | Train Acc: 52.34%
# Val Loss: 2.0642 | Top-1 Val Acc: 46.56% | Top-5 Val Acc: 75.02%
#
# Epoch 24/100
# --------------------
# Train Loss: 1.8014 | Train Acc: 52.37%
# Val Loss: 2.0607 | Top-1 Val Acc: 47.04% | Top-5 Val Acc: 74.64%
# [✓] Saved best model (Top-1 = 47.04%)
#
# Epoch 25/100
# --------------------
# Train Loss: 1.7972 | Train Acc: 52.61%
# Val Loss: 2.0580 | Top-1 Val Acc: 47.04% | Top-5 Val Acc: 75.04%
#
# Epoch 26/100
# --------------------
# Train Loss: 1.7909 | Train Acc: 52.68%
# Val Loss: 2.0572 | Top-1 Val Acc: 47.06% | Top-5 Val Acc: 74.98%
# [✓] Saved best model (Top-1 = 47.06%)
#
# Epoch 27/100
# --------------------
# Train Loss: 1.7979 | Train Acc: 52.65%
# Val Loss: 2.0665 | Top-1 Val Acc: 46.72% | Top-5 Val Acc: 74.86%
#
# Epoch 28/100
# --------------------
# Train Loss: 1.7908 | Train Acc: 52.69%
# Val Loss: 2.0648 | Top-1 Val Acc: 46.50% | Top-5 Val Acc: 74.82%
#
# Epoch 29/100
# --------------------
# Train Loss: 1.7883 | Train Acc: 52.91%
# Val Loss: 2.0623 | Top-1 Val Acc: 46.76% | Top-5 Val Acc: 75.04%
#
# Epoch 30/100
# --------------------
# Train Loss: 1.7915 | Train Acc: 52.85%
# Val Loss: 2.0609 | Top-1 Val Acc: 46.94% | Top-5 Val Acc: 74.98%
#
# Epoch 31/100
# --------------------
# Train Loss: 2.6822 | Train Acc: 33.81%
# Val Loss: 2.8424 | Top-1 Val Acc: 30.64% | Top-5 Val Acc: 60.60%
#
# Epoch 32/100
# --------------------
# Train Loss: 2.3517 | Train Acc: 40.29%
# Val Loss: 2.5591 | Top-1 Val Acc: 35.70% | Top-5 Val Acc: 66.00%
#
# Epoch 33/100
# --------------------
# Train Loss: 2.2006 | Train Acc: 43.39%
# Val Loss: 2.4272 | Top-1 Val Acc: 38.38% | Top-5 Val Acc: 68.08%
#
# Epoch 34/100
# --------------------
# Train Loss: 2.1197 | Train Acc: 45.14%
# Val Loss: 2.3292 | Top-1 Val Acc: 40.82% | Top-5 Val Acc: 70.78%
#
# Epoch 35/100
# --------------------
# Train Loss: 2.0537 | Train Acc: 46.77%
# Val Loss: 2.2375 | Top-1 Val Acc: 42.48% | Top-5 Val Acc: 72.36%
#
# Epoch 36/100
# --------------------
# Train Loss: 1.9948 | Train Acc: 47.89%
# Val Loss: 2.2606 | Top-1 Val Acc: 41.94% | Top-5 Val Acc: 70.92%
#
# Epoch 37/100
# --------------------
# Train Loss: 1.9526 | Train Acc: 49.01%
# Val Loss: 2.2333 | Top-1 Val Acc: 43.00% | Top-5 Val Acc: 72.18%
#
# Epoch 38/100
# --------------------
# Train Loss: 1.9063 | Train Acc: 50.04%
# Val Loss: 2.2097 | Top-1 Val Acc: 43.42% | Top-5 Val Acc: 72.50%
#
# Epoch 39/100
# --------------------
# Train Loss: 1.8683 | Train Acc: 50.74%
# Val Loss: 2.1114 | Top-1 Val Acc: 45.32% | Top-5 Val Acc: 75.04%
#
# Epoch 40/100
# --------------------
# Train Loss: 1.8375 | Train Acc: 51.57%
# Val Loss: 2.1758 | Top-1 Val Acc: 43.66% | Top-5 Val Acc: 73.42%
#
# Epoch 41/100
# --------------------
# Train Loss: 1.8010 | Train Acc: 52.49%
# Val Loss: 2.1331 | Top-1 Val Acc: 45.26% | Top-5 Val Acc: 73.76%
#
# Epoch 42/100
# --------------------
# Train Loss: 1.7740 | Train Acc: 52.94%
# Val Loss: 2.1340 | Top-1 Val Acc: 45.76% | Top-5 Val Acc: 74.32%
#
# Epoch 43/100
# --------------------
# Train Loss: 1.7450 | Train Acc: 53.68%
# Val Loss: 1.9797 | Top-1 Val Acc: 47.88% | Top-5 Val Acc: 77.44%
# [✓] Saved best model (Top-1 = 47.88%)
#
# Epoch 44/100
# --------------------
# Train Loss: 1.7215 | Train Acc: 54.21%
# Val Loss: 1.9623 | Top-1 Val Acc: 49.16% | Top-5 Val Acc: 77.08%
# [✓] Saved best model (Top-1 = 49.16%)
#
# Epoch 45/100
# --------------------
# Train Loss: 1.7055 | Train Acc: 54.69%
# Val Loss: 1.9747 | Top-1 Val Acc: 48.50% | Top-5 Val Acc: 76.82%
#
# Epoch 46/100
# --------------------
# Train Loss: 1.6873 | Train Acc: 55.06%
# Val Loss: 1.9941 | Top-1 Val Acc: 48.62% | Top-5 Val Acc: 76.52%
#
# Epoch 47/100
# --------------------
# Train Loss: 1.6621 | Train Acc: 55.63%
# Val Loss: 1.9424 | Top-1 Val Acc: 49.40% | Top-5 Val Acc: 76.70%
# [✓] Saved best model (Top-1 = 49.40%)
#
# Epoch 48/100
# --------------------
# Train Loss: 1.6489 | Train Acc: 56.01%
# Val Loss: 1.9591 | Top-1 Val Acc: 49.48% | Top-5 Val Acc: 76.58%
# [✓] Saved best model (Top-1 = 49.48%)
#
# Epoch 49/100
# --------------------
# Train Loss: 1.6276 | Train Acc: 56.61%
# Val Loss: 1.9911 | Top-1 Val Acc: 48.30% | Top-5 Val Acc: 76.66%
#
# Epoch 50/100
# --------------------
# Train Loss: 1.6149 | Train Acc: 56.84%
# Val Loss: 1.9700 | Top-1 Val Acc: 48.94% | Top-5 Val Acc: 76.66%
#
# Epoch 51/100
# --------------------
# Train Loss: 1.6004 | Train Acc: 57.38%
# Val Loss: 1.9320 | Top-1 Val Acc: 50.22% | Top-5 Val Acc: 77.60%
# [✓] Saved best model (Top-1 = 50.22%)
#
# Epoch 52/100
# --------------------
# Train Loss: 1.5819 | Train Acc: 57.67%
# Val Loss: 1.9435 | Top-1 Val Acc: 49.44% | Top-5 Val Acc: 77.58%
#
# Epoch 53/100
# --------------------
# Train Loss: 1.5701 | Train Acc: 57.86%
# Val Loss: 1.9624 | Top-1 Val Acc: 49.66% | Top-5 Val Acc: 76.82%
#
# Epoch 54/100
# --------------------
# Train Loss: 1.5563 | Train Acc: 58.19%
# Val Loss: 1.9109 | Top-1 Val Acc: 51.08% | Top-5 Val Acc: 78.06%
# [✓] Saved best model (Top-1 = 51.08%)
#
# Epoch 55/100
# --------------------
# Train Loss: 1.5474 | Train Acc: 58.59%
# Val Loss: 1.9970 | Top-1 Val Acc: 49.16% | Top-5 Val Acc: 76.84%
#
# Epoch 56/100
# --------------------
# Train Loss: 1.5363 | Train Acc: 58.72%
# Val Loss: 1.9405 | Top-1 Val Acc: 50.28% | Top-5 Val Acc: 76.98%
#
# Epoch 57/100
# --------------------
# Train Loss: 1.5258 | Train Acc: 58.98%
# Val Loss: 1.9579 | Top-1 Val Acc: 50.24% | Top-5 Val Acc: 76.96%
#
# Epoch 58/100
# --------------------
# Train Loss: 1.5128 | Train Acc: 59.30%
# Val Loss: 1.9237 | Top-1 Val Acc: 50.68% | Top-5 Val Acc: 78.00%
#
# Epoch 59/100
# --------------------
# Train Loss: 1.5041 | Train Acc: 59.60%
# Val Loss: 1.9464 | Top-1 Val Acc: 51.08% | Top-5 Val Acc: 77.18%
#
# Epoch 60/100
# --------------------
# Train Loss: 1.5046 | Train Acc: 59.55%
# Val Loss: 1.9256 | Top-1 Val Acc: 50.44% | Top-5 Val Acc: 77.82%
#
# Epoch 61/100
# --------------------
# Train Loss: 1.2559 | Train Acc: 65.87%
# Val Loss: 1.5350 | Top-1 Val Acc: 59.46% | Top-5 Val Acc: 83.84%
# [✓] Saved best model (Top-1 = 59.46%)
#
# Epoch 62/100
# --------------------
# Train Loss: 1.1720 | Train Acc: 68.00%
# Val Loss: 1.5084 | Top-1 Val Acc: 59.90% | Top-5 Val Acc: 84.28%
# [✓] Saved best model (Top-1 = 59.90%)
#
# Epoch 63/100
# --------------------
# Train Loss: 1.1347 | Train Acc: 68.92%
# Val Loss: 1.4939 | Top-1 Val Acc: 60.66% | Top-5 Val Acc: 84.56%
# [✓] Saved best model (Top-1 = 60.66%)
#
# Epoch 64/100
# --------------------
# Train Loss: 1.1175 | Train Acc: 69.37%
# Val Loss: 1.4788 | Top-1 Val Acc: 61.08% | Top-5 Val Acc: 84.92%
# [✓] Saved best model (Top-1 = 61.08%)
#
# Epoch 65/100
# --------------------
# Train Loss: 1.0976 | Train Acc: 69.83%
# Val Loss: 1.4987 | Top-1 Val Acc: 60.76% | Top-5 Val Acc: 84.02%
#
# Epoch 66/100
# --------------------
# Train Loss: 1.0829 | Train Acc: 70.22%
# Val Loss: 1.4902 | Top-1 Val Acc: 60.46% | Top-5 Val Acc: 84.48%
#
# Epoch 67/100
# --------------------
# Train Loss: 1.0619 | Train Acc: 70.64%
# Val Loss: 1.4785 | Top-1 Val Acc: 61.10% | Top-5 Val Acc: 84.74%
# [✓] Saved best model (Top-1 = 61.10%)
#
# Epoch 68/100
# --------------------
# Train Loss: 1.0562 | Train Acc: 70.91%
# Val Loss: 1.4907 | Top-1 Val Acc: 61.04% | Top-5 Val Acc: 84.66%
#
# Epoch 69/100
# --------------------
# Train Loss: 1.0476 | Train Acc: 71.13%
# Val Loss: 1.4754 | Top-1 Val Acc: 61.52% | Top-5 Val Acc: 84.68%
# [✓] Saved best model (Top-1 = 61.52%)
#
# Epoch 70/100
# --------------------
# Train Loss: 1.0268 | Train Acc: 71.65%
# Val Loss: 1.4777 | Top-1 Val Acc: 61.62% | Top-5 Val Acc: 84.86%
# [✓] Saved best model (Top-1 = 61.62%)
#
# Epoch 71/100
# --------------------
# Train Loss: 1.0222 | Train Acc: 71.75%
# Val Loss: 1.4747 | Top-1 Val Acc: 61.68% | Top-5 Val Acc: 84.80%
# [✓] Saved best model (Top-1 = 61.68%)
#
# Epoch 72/100
# --------------------
# Train Loss: 1.0156 | Train Acc: 71.94%
# Val Loss: 1.4650 | Top-1 Val Acc: 61.82% | Top-5 Val Acc: 84.82%
# [✓] Saved best model (Top-1 = 61.82%)
#
# Epoch 73/100
# --------------------
# Train Loss: 1.0022 | Train Acc: 72.23%
# Val Loss: 1.4834 | Top-1 Val Acc: 61.24% | Top-5 Val Acc: 84.54%
#
# Epoch 74/100
# --------------------
# Train Loss: 0.9956 | Train Acc: 72.49%
# Val Loss: 1.4652 | Top-1 Val Acc: 61.74% | Top-5 Val Acc: 84.94%
#
# Epoch 75/100
# --------------------
# Train Loss: 0.9802 | Train Acc: 72.92%
# Val Loss: 1.4769 | Top-1 Val Acc: 61.62% | Top-5 Val Acc: 84.62%
#
# Epoch 76/100
# --------------------
# Train Loss: 0.9739 | Train Acc: 73.00%
# Val Loss: 1.4816 | Top-1 Val Acc: 61.10% | Top-5 Val Acc: 84.88%
#
# Epoch 77/100
# --------------------
# Train Loss: 0.9713 | Train Acc: 73.10%
# Val Loss: 1.4719 | Top-1 Val Acc: 61.76% | Top-5 Val Acc: 85.08%
#
# Epoch 78/100
# --------------------
# Train Loss: 0.9604 | Train Acc: 73.38%
# Val Loss: 1.4839 | Top-1 Val Acc: 62.12% | Top-5 Val Acc: 84.78%
# [✓] Saved best model (Top-1 = 62.12%)
#
# Epoch 79/100
# --------------------
# Train Loss: 0.9579 | Train Acc: 73.51%
# Val Loss: 1.4820 | Top-1 Val Acc: 62.74% | Top-5 Val Acc: 84.66%
# [✓] Saved best model (Top-1 = 62.74%)
#
# Epoch 80/100
# --------------------
# Train Loss: 0.9445 | Train Acc: 73.79%
# Val Loss: 1.4906 | Top-1 Val Acc: 61.82% | Top-5 Val Acc: 85.06%
#
# Epoch 81/100
# --------------------
# Train Loss: 0.9365 | Train Acc: 73.83%
# Val Loss: 1.4889 | Top-1 Val Acc: 61.98% | Top-5 Val Acc: 84.84%
#
# Epoch 82/100
# --------------------
# Train Loss: 0.9307 | Train Acc: 74.30%
# Val Loss: 1.5169 | Top-1 Val Acc: 61.38% | Top-5 Val Acc: 84.84%
#
# Epoch 83/100
# --------------------
# Train Loss: 0.9251 | Train Acc: 74.34%
# Val Loss: 1.4944 | Top-1 Val Acc: 62.38% | Top-5 Val Acc: 85.24%
#
# Epoch 84/100
# --------------------
# Train Loss: 0.9144 | Train Acc: 74.60%
# Val Loss: 1.5004 | Top-1 Val Acc: 61.54% | Top-5 Val Acc: 85.22%
#
# Epoch 85/100
# --------------------
# Train Loss: 0.9167 | Train Acc: 74.55%
# Val Loss: 1.4952 | Top-1 Val Acc: 62.06% | Top-5 Val Acc: 84.74%
#
# Epoch 86/100
# --------------------
# Train Loss: 0.9064 | Train Acc: 74.70%
# Val Loss: 1.5062 | Top-1 Val Acc: 61.78% | Top-5 Val Acc: 84.76%
#
# Epoch 87/100
# --------------------
# Train Loss: 0.8987 | Train Acc: 75.04%
# Val Loss: 1.5018 | Top-1 Val Acc: 61.62% | Top-5 Val Acc: 85.12%
#
# Epoch 88/100
# --------------------
# Train Loss: 0.8938 | Train Acc: 75.20%
# Val Loss: 1.5190 | Top-1 Val Acc: 62.02% | Top-5 Val Acc: 84.60%
#
# Epoch 89/100
# --------------------
# Train Loss: 0.8892 | Train Acc: 75.22%
# Val Loss: 1.5041 | Top-1 Val Acc: 62.34% | Top-5 Val Acc: 84.60%
#
# Epoch 90/100
# --------------------
# Train Loss: 0.8807 | Train Acc: 75.45%
# Val Loss: 1.5338 | Top-1 Val Acc: 61.10% | Top-5 Val Acc: 84.66%
#
# Epoch 91/100
# --------------------
# Train Loss: 0.8291 | Train Acc: 77.00%
# Val Loss: 1.4850 | Top-1 Val Acc: 62.16% | Top-5 Val Acc: 85.14%
#
# Epoch 92/100
# --------------------
# Train Loss: 0.8120 | Train Acc: 77.58%
# Val Loss: 1.4848 | Top-1 Val Acc: 62.72% | Top-5 Val Acc: 85.14%
#
# Epoch 93/100
# --------------------
# Train Loss: 0.7998 | Train Acc: 77.78%
# Val Loss: 1.4815 | Top-1 Val Acc: 62.60% | Top-5 Val Acc: 85.18%
#
# Epoch 94/100
# --------------------
# Train Loss: 0.8059 | Train Acc: 77.72%
# Val Loss: 1.4843 | Top-1 Val Acc: 62.86% | Top-5 Val Acc: 85.44%
# [✓] Saved best model (Top-1 = 62.86%)
#
# Epoch 95/100
# --------------------
# Train Loss: 0.7932 | Train Acc: 77.93%
# Val Loss: 1.4971 | Top-1 Val Acc: 62.26% | Top-5 Val Acc: 85.24%
#
# Epoch 96/100
# --------------------
# Train Loss: 0.7956 | Train Acc: 78.03%
# Val Loss: 1.4896 | Top-1 Val Acc: 62.38% | Top-5 Val Acc: 85.48%
#
# Epoch 97/100
# --------------------
# Train Loss: 0.7853 | Train Acc: 78.31%
# Val Loss: 1.4839 | Top-1 Val Acc: 62.48% | Top-5 Val Acc: 85.54%
#
# Epoch 98/100
# --------------------
# Train Loss: 0.7882 | Train Acc: 78.37%
# Val Loss: 1.4850 | Top-1 Val Acc: 62.72% | Top-5 Val Acc: 85.58%
#
# Epoch 99/100
# --------------------
# Train Loss: 0.7853 | Train Acc: 78.16%
# Val Loss: 1.4871 | Top-1 Val Acc: 62.94% | Top-5 Val Acc: 85.44%
# [✓] Saved best model (Top-1 = 62.94%)
#
# Epoch 100/100
# --------------------
# Train Loss: 0.7772 | Train Acc: 78.46%
# Val Loss: 1.4893 | Top-1 Val Acc: 62.76% | Top-5 Val Acc: 85.36%
# [✓] Saved epoch metrics to results/per_model_logs/ResNet34_ImageNet100_metrics.csv
# [✓] Appended model summary to results/summary/final_model_comparison.csv
# Train time on cuda : 15541.654 seconds
# [✓] Training complete for ResNet34_ImageNet100
